# %%
import pickle
import numpy as np
import pandas as pd

# %%
# !pipenv --version
# Out:
# pipenv, version 2022.9.24

# %%
# !pipenv install scikit-learn
# Out:
# Installing scikit-learn...
# Installing dependencies from Pipfile.lock (b880b8)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Creating a virtualenv for this project...
#
# Pipfile: C:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\05_homework\Pipfile
#
# Using C:/ProgramData/Anaconda3/python.exe (3.9.13) to create virtualenv...
#
#
# [    ] Creating virtual environment..
# [=   ] Creating virtual environment..
# [==  ] Creating virtual environment..
# [=== ] Creating virtual environment..
# [ ===] Creating virtual environment..
# [  ==] Creating virtual environment..
# [   =] Creating virtual environment..
# [    ] Creating virtual environment..
# [   =] Creating virtual environment..
# [  ==] Creating virtual environment..
# [ ===] Creating virtual environment..
# [====] Creating virtual environment..
# [=== ] Creating virtual environment..
# [==  ] Creating virtual environment..
# ...

# %%
print("sha256: 5ac544a315afd6c33fb82f53ee605c09ec8f2a8b1a4090deaf58a0a4ffb880b8")
# Out:
# sha256: 5ac544a315afd6c33fb82f53ee605c09ec8f2a8b1a4090deaf58a0a4ffb880b8

# %%
# !pipenv install gunicorn
# Out:
# Installing gunicorn...
#
# Installing dependencies from Pipfile.lock (d518f6)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# [    ] Installing..
# [=   ] Installing gunicorn..
# [==  ] Installing gunicorn..
# [=== ] Installing gunicorn..
# [ ===] Installing gunicorn..
# [  ==] Installing gunicorn..
# [   =] Installing gunicorn..
# [    ] Installing gunicorn..
# [   =] Installing gunicorn..
# [  ==] Installing gunicorn..
# [ ===] Installing gunicorn..
# [====] Installing gunicorn..
# [=== ] Installing gunicorn..
# [==  ] Installing gunicorn..
# [=   ] Installing gunicorn..
# [    ] Installing gunicorn..
# [=   ] Installing gunicorn..
# [==  ] Installing gunicorn..
# [=== ] Installing gunicorn..
# [ ===] Installing gunicorn..
# [  ==] Installing gunicorn..
# [   =] Installing gunicorn..
# [    ] Installing gunicorn..
# [   =] Installing gunicorn..
# [  ==] Installing gunicorn..
# ...

# %%
# !PREFIX=https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp/cohorts/2022/05-deployment/homework
# !wget $PREFIX/model1.bin
# !wget $PREFIX/dv.bin
# Out:
# 'PREFIX' is not recognized as an internal or external command,
# operable program or batch file.
# --2022-10-09 15:16:48--  http://$prefix/model1.bin
# Resolving $prefix ($prefix)... failed: Name or service not known.
# wget: unable to resolve host address '$prefix'
# --2022-10-09 15:16:48--  http://$prefix/dv.bin
# Resolving $prefix ($prefix)... failed: Name or service not known.
# wget: unable to resolve host address '$prefix'
