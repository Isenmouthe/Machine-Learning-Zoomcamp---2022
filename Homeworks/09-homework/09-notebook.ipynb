# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Let's install TF-lite

# %%
#!pip install tflite-runtime
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Converting keras model into TF-lite model

# %%
'''
model = keras.models.load_model('dino_dragon_10_0.899.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open('model.tflite', 'wb') as f_out:
    f_out.write(tflite_model)
'''
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os 
size_tf_model = os.path.getsize("model.tflite")
print(size_tf_model/(1024*1024))
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# What's the size of the **converte** model?
#
# answer: 43

# %%
import tflite_runtime.interpreter as tflite
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
interpreter = tf.lite.Interpreter(model_path='model.tflite')
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]['index']
output_index = interpreter.get_output_details()[0]['index']
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(f'Output index is : {output_index}')
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# What's the output index for this model?
#
# Answer: 13

# %%
from io import BytesIO
from urllib import request

from PIL import Image

def download_image(url):
    with request.urlopen(url) as resp:
        buffer = resp.read()
    stream = BytesIO(buffer)
    img = Image.open(stream)
    return img


def prepare_image(img, target_size):
    if img.mode != 'RGB':
        img = img.convert('RGB')
    img = img.resize(target_size, Image.NEAREST)
    return img
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img = download_image('https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Smaug_par_David_Demaret.jpg/1280px-Smaug_par_David_Demaret.jpg')

img = prepare_image(img, target_size=(150, 150))

img
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def prepare_input(x):
    return x/255.0
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
x = np.array(img, dtype='float32')
X = np.array([x])
X = prepare_input(X)
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(f'The value in the first pixel, the R channel is: {X[0,0,0,0]}')
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
interpreter.set_tensor(input_index, X)
interpreter.invoke()
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
preds = interpreter.get_tensor(output_index)
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(f'The output of the model is {preds}')
# Out:
# Failed to start the Kernel.
#
# 2022-11-25 16:51:09.246056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
#
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# 2022-11-25 16:51:10.474452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#
# 2022-11-25 16:51:14.288372: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
#
# 2022-11-25 16:51:14.288603: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
#
# 2022-11-25 16:51:14.291883: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.297799: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
#
# 2022-11-25 16:51:14.297996: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.309679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
#
# 2022-11-25 16:51:14.311609: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
#
# 2022-11-25 16:51:14.548690: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: C:\Users\levan\AppData\Local\Temp\tmpomavi9hf
#
# 2022-11-25 16:51:14.558373: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 266487 microseconds.
#
# 2022-11-25 16:51:14.621474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#
# Traceback (most recent call last):
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "c:\Users\levan\anaconda3\lib\runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 51, in <module>
#
#     from .ipkernel import IPythonKernel
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 19, in <module>
#
#     from .debugger import Debugger, _is_debugpy_available
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\ipykernel\debugger.py", line 22, in <module>
#
#     from debugpy.server import api  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\server\__init__.py", line 9, in <module>
#
#     import debugpy._vendored.force_pydevd  # noqa
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\force_pydevd.py", line 37, in <module>
#
#     pydevd_constants = import_module('_pydevd_bundle.pydevd_constants')
#
#   File "c:\Users\levan\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_constants.py", line 365, in <module>
#
#     from _pydev_imps._pydev_saved_modules import thread, threading
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 93, in <module>
#
#     import code as _code;    verify_shadowed.check(_code, ['compile_command', 'InteractiveInterpreter'])
#
#   File "c:\Users\levan\anaconda3\lib\site-packages\debugpy\_vendored\pydevd\_pydev_imps\_pydev_saved_modules.py", line 77, in check
#
#     raise DebuggerInitializationError(msg)
#
# _pydev_imps._pydev_saved_modules.DebuggerInitializationError: It was not possible to initialize the debugger due to a module name conflict.
#
#
#
# i.e.: the module "code" could not be imported because it is shadowed by:
#
# c:\Users\levan\Desktop\Machine Learning Zoomcamp - 2022\Homeworks\09-homework\code.py
#
# Please rename this file/folder so that the original module from the standard library can be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
